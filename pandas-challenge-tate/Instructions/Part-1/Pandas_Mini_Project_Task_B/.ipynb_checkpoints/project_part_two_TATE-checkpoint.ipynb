# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csv = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types

# %%
# Read with pandas
df = pd.read_csv(csv, low_memory=False)
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
new_df = df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
new_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
new_df = new_df.replace({0.0: "No", 1.0: "Yes"})
new_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
#Extract row for only those who attended a bootcamp.
attended = new_df.loc[new_df["AttendedBootcamp"]=="Yes", :]
attended.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampName            895
# BootcampPostSalary      330
# BootcampRecommend       937
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
bootcamp_name = pd.DataFrame(attended["BootcampName"].value_counts())
bootcamp_name.reset_index(inplace=True)
bootcamp_name.columns = ["BootcampName", "Count"]

#Extract schools with sufficient responses. 
#bootcamp_name = bootcamp_name.loc[(bootcamp_name["Count"] > 9) &
                                  #(bootcamp_name["BootcampName"] != 'Free Code Camp is not a bootcamp - please scroll up and change answer to "no"')
bootcamp_name.head()
# Out:
#             BootcampName  Count
# 0       General Assembly     90
# 1        Flatiron School     54
# 2           Dev Bootcamp     48
# 3          The Iron Yard     40
# 4  Prime Digital Academy     30

# %%
#Create another DataFrame with two columns: One for the bootcamp name, and one for the number of respondents who recommend it.
attended = attended.replace({"No": 0, "Yes": 1})
bootcamp_recommend = pd.DataFrame(attended.groupby("BootcampName")["BootcampRecommend"].sum())
bootcamp_recommend.reset_index(inplace=True)
bootcamp_recommend.columns = ["BootcampName", "Recommended"]

bootcamp_recommend.head()
# Out:
#             BootcampName  Recommended
# 0             10x.org.il          3.0
# 1         4Geeks Academy          4.0
# 2               AcadGild          2.0
# 3     Academia de Código          4.0
# 4  Academic Work Academy          0.0

# %%
merged = pd.merge(bootcamp_name, bootcamp_recommend)
merged
# Out:
#                                           BootcampName  Count  Recommended
# 0                                     General Assembly     90         70.0
# 1                                      Flatiron School     54         50.0
# 2                                         Dev Bootcamp     48         41.0
# 3                                        The Iron Yard     40         31.0
# 4                                Prime Digital Academy     30         25.0
# 5                                         Hack Reactor     29         27.0
# 6                                               Turing     27         26.0
# 7                                          App Academy     22         20.0
# 8                                   Hackbright Academy     22         19.0
# 9                                         Code Fellows     21         15.0
# 10                                             Bloc.io     21         11.0
# ...

# %%
student_percent = (merged["Recommended"] / merged["Count"]) * 100
student_percent
# Out:
# 0       77.777778
# 1       92.592593
# 2       85.416667
# 3       77.500000
# 4       83.333333
# 5       93.103448
# 6       96.296296
# 7       90.909091
# 8       86.363636
# 9       71.428571
# 10      52.380952
# 11      90.000000
# 12      55.000000
# 13      70.000000
# 14      61.111111
# 15      81.250000
# 16      93.333333
# 17      78.571429
# 18     100.000000
# 19     100.000000
# 20      66.666667
# 21      54.545455
# 22      80.000000
# 23      80.000000
# 24     100.000000
# 25      60.000000
# 26      80.000000
# 27      88.888889
# 28      50.000000
# 29     100.000000
#           ...
# 98       0.000000
# 99     100.000000
# 100    100.000000
# 101    100.000000
# 102    100.000000
# 103    100.000000
# 104    100.000000
# 105    100.000000
# 106    100.000000
# 107    100.000000
# 108    100.000000
# 109    100.000000
# 110    100.000000
# 111    100.000000
# 112    100.000000
# 113    100.000000
# 114    100.000000
# 115    100.000000
# 116      0.000000
# ...

# %%
merged["%Recommended"] = (merged["Recommended"] / merged["Count"]) * 100

merged.sort_values(["%Recommended"], ascending=False).round(2)

merged["%Recommended"] = merged["%Recommended"].map("{0:,.2f}%".format)

merged.head()

#student_percent.sort_values(by=[1], ascending=True)
# Out:
#             BootcampName  Count  Recommended %Recommended
# 0       General Assembly     90         70.0       77.78%
# 1        Flatiron School     54         50.0       92.59%
# 2           Dev Bootcamp     48         41.0       85.42%
# 3          The Iron Yard     40         31.0       77.50%
# 4  Prime Digital Academy     30         25.0       83.33%

# %%
# Calculate percentage of eac bootcamp's students who are recommenders

# %%
# Export to excel and remove index

merged.to_csv("Output/bootcamp_part2.csv", index=False, header=True)
