# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1ccd61e4550>,
#   <matplotlib.axis.XTick at 0x1ccd61c8e48>,
#   <matplotlib.axis.XTick at 0x1ccd61c88d0>,
#   <matplotlib.axis.XTick at 0x1ccd62a11d0>,
#   <matplotlib.axis.XTick at 0x1ccd62a1668>,
#   <matplotlib.axis.XTick at 0x1ccd62a1be0>,
#   <matplotlib.axis.XTick at 0x1ccd62b1198>,
#   <matplotlib.axis.XTick at 0x1ccd62b1710>,
#   <matplotlib.axis.XTick at 0x1ccd62a1240>,
#   <matplotlib.axis.XTick at 0x1ccd62b1da0>,
#   <matplotlib.axis.XTick at 0x1ccd62b6160>,
#   <matplotlib.axis.XTick at 0x1ccd62b66a0>,
#   <matplotlib.axis.XTick at 0x1ccd62b6c18>,
#   <matplotlib.axis.XTick at 0x1ccd62be1d0>,
#   <matplotlib.axis.XTick at 0x1ccd62be748>,
#   <matplotlib.axis.XTick at 0x1ccd62becc0>,
#   <matplotlib.axis.XTick at 0x1ccd62c6278>,
#   <matplotlib.axis.XTick at 0x1ccd62be278>,
#   <matplotlib.axis.XTick at 0x1ccd62b6668>,
#   <matplotlib.axis.XTick at 0x1ccd62c6a58>,
#   <matplotlib.axis.XTick at 0x1ccd62c6dd8>,
#   <matplotlib.axis.XTick at 0x1ccd62cc390>,
#   <matplotlib.axis.XTick at 0x1ccd62cc908>,
#   <matplotlib.axis.XTick at 0x1ccd62cce80>,
#   <matplotlib.axis.XTick at 0x1ccd62d3438>,
#   <matplotlib.axis.XTick at 0x1ccd62d39b0>,
#   <matplotlib.axis.XTick at 0x1ccd62d3f28>,
#   <matplotlib.axis.XTick at 0x1ccd62d3908>,
#   <matplotlib.axis.XTick at 0x1ccd62c6d30>,
#   <matplotlib.axis.XTick at 0x1ccd62da400>,
#   <matplotlib.axis.XTick at 0x1ccd62da978>,
#   <matplotlib.axis.XTick at 0x1ccd62daef0>,
#   <matplotlib.axis.XTick at 0x1ccd62e14a8>,
#   <matplotlib.axis.XTick at 0x1ccd62e1a20>,
#   <matplotlib.axis.XTick at 0x1ccd62e1e80>,
#   <matplotlib.axis.XTick at 0x1ccd62e7550>,
#   <matplotlib.axis.XTick at 0x1ccd62e1400>,
#   <matplotlib.axis.XTick at 0x1ccd62da780>,
#   <matplotlib.axis.XTick at 0x1ccd62e7710>,
#   <matplotlib.axis.XTick at 0x1ccd62e7630>,
#   <matplotlib.axis.XTick at 0x1ccd62ef588>,
#   <matplotlib.axis.XTick at 0x1ccd62efb00>,
#   <matplotlib.axis.XTick at 0x1ccd62f6128>,
#   <matplotlib.axis.XTick at 0x1ccd62f6630>,
#   <matplotlib.axis.XTick at 0x1ccd62f6ba8>,
#   <matplotlib.axis.XTick at 0x1ccd62ff198>,
#   <matplotlib.axis.XTick at 0x1ccd62f6a20>,
#   <matplotlib.axis.XTick at 0x1ccd62e7dd8>,
#   <matplotlib.axis.XTick at 0x1ccd62ff5f8>,
#   <matplotlib.axis.XTick at 0x1ccd62ffb70>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
