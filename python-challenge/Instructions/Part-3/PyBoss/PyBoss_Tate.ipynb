# %%
# Import required packages
import pandas as pd

# %%
# Files to load and output (Remember to change these)
boss_df = "employee_data.csv"
out_df = "employee_data_reformatted.csv"

# %%
# Dictionary of states with abbreviations
us_state_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
}

# %%
# Placeholders for re-formatted contents
#emp_ids = []
#emp_first_names = []
#emp_last_names = []
#emp_dobs = []
#emp_ssns = []
#emp_states = []

# %%
# Read the csv and convert it into a list of dictionaries
boss_df = pd.read_csv(boss_df)
boss_df.head()
# Out:
#    Emp ID              Name         DOB          SSN         State
# 0     232      John Mathews  1991-02-24  289-31-9165  North Dakota
# 1     533      Nathan Moore  1978-11-19  220-05-7469         Maine
# 2     256    Amanda Douglas  1990-01-08  564-27-6961         Idaho
# 3     189   Heather Andrews  1976-08-11  742-79-1797       Vermont
# 4     284  Daniel Hernandez  1976-07-22  656-01-7473      Colorado

# %%
#boss_df["Name"] = pd.cut(boss_df["First Name":"Last Name"])

boss_df["First Name"] = boss_df["Name"].str.split(0:)

boss_df["Last Name"] = boss_df["Name"].str.split

boss_df.
# Out:
#      Emp ID                Name         DOB          SSN          State  \
# 0       232        John Mathews  1991-02-24  289-31-9165   North Dakota
# 1       533        Nathan Moore  1978-11-19  220-05-7469          Maine
# 2       256      Amanda Douglas  1990-01-08  564-27-6961          Idaho
# 3       189     Heather Andrews  1976-08-11  742-79-1797        Vermont
# 4       284    Daniel Hernandez  1976-07-22  656-01-7473       Colorado
# 5       512          Danny Pena  1978-01-31  158-33-9878      Minnesota
# 6       126         Gary Knight  1994-03-08  782-25-1242       Arkansas
# 7       556       Robin Carroll  1972-10-14  606-48-7194     California
# 8       595  Michelle Dickerson  1984-02-08  707-24-2817      Tennessee
# 9       191   Kimberly Gallegos  1972-08-05  653-52-7563         Oregon
# 10       55       Morgan Parker  1986-01-30  692-70-4320      Tennessee
# 11      623        Mason Rhodes  1977-01-28  841-07-4767       Maryland
# 12      426         Amy Griffin  1973-02-18  241-86-1946  Massachusetts
# 13      535      Danielle House  1975-04-16  350-25-9308          Maine
# 14      399      Charles Greene  1992-11-28  299-23-2935       Kentucky
# 15       33   Nicholas Martinez  1979-04-05  122-26-1689      Louisiana
# 16      302      Tracey Meadows  1988-01-12  642-22-6175   Rhode Island
# 17      325         Renee Evans  1991-03-14  748-42-2708        Montana
# 18      188      Joseph Estrada  1984-03-29  246-57-2571   Pennsylvania
# 19      184       Jeremy Warner  1987-10-20  423-43-1184        Alabama
# 20      526   Anthony Rodriguez  1983-02-09  843-84-3865          Idaho
# 21       85       Kristen Lopez  1978-01-02  364-04-8194       Virginia
# 22      171       Mark Mcdonald  1984-06-27  053-77-0101        Montana
# 2        [Amanda, Douglas]
# 3       [Heather, Andrews]
# 4      [Daniel, Hernandez]
# 5            [Danny, Pena]
# 6           [Gary, Knight]
# 7         [Robin, Carroll]
# 8    [Michelle, Dickerson]
# 9     [Kimberly, Gallegos]
# 10        [Morgan, Parker]
# 11         [Mason, Rhodes]
# 12          [Amy, Griffin]
# 13       [Danielle, House]
# 14       [Charles, Greene]
# 15    [Nicholas, Martinez]
# 16       [Tracey, Meadows]
# 17          [Renee, Evans]
# 18       [Joseph, Estrada]
# 19        [Jeremy, Warner]
# 20    [Anthony, Rodriguez]
# 21        [Kristen, Lopez]
# 22        [Mark, Mcdonald]
# 23       [Robert, Freeman]
# 24     [Michael, Reynolds]
# 25      [Kristine, Little]
# 26         [April, Barnes]
# 27        [Pamela, Hodges]
# 28       [Ronald, Gilbert]
# 29        [Thomas, Cooper]
# ..                     ...
# 620        [Leslie, Brown]
# 621       [Maria, Chapman]
# 622      [Melissa, Torres]
# 623       [Joshua, Weaver]
# 624      [Crystal, Martin]
# 625          [Sheri, Ball]
# 626       [Steven, Ritter]
# 627        [Linda, Krause]
# 628          [John, Myers]
# 629          [Mark, White]
# 630         [Diana, Smith]
# 631         [Karen, Lyons]
# 632         [Laura, Glenn]
# 633        [Diana, Spence]
# 634     [Samantha, Farley]
# 635      [Kayla, Mitchell]
# 636       [Crystal, Myers]
# 637        [Brooke, Jones]
# 638        [John, Mueller]
# 639       [Karla, Rosales]
# 640      [Jennifer, Brown]
# 641       [Blake, Jimenez]
# 642      [Michael, Garcia]
# 643      [Jermaine, Quinn]
# 644       [Patricia, Cruz]
# 645    [Cameron, Mcintosh]
# 646     [Michelle, Brewer]
# 647        [Hannah, Nolan]
# 648       [Erica, Johnson]
# 649       [Jeremy, Obrien]
#
# [650 rows x 6 columns]

# %%
# Loop through each row, re-grab each field and store in a new list
    for row in reader:

        # Grab emp_ids and store it into a list
        emp_ids = emp_ids + [row[0]]

        # Grab names, split them, and store them in a temporary variable
        split_name = row[1].split(" ")

        # Then save first and last name in separate lists
        # YOUR CODE HERE

        # Grab DOB and reformat it
        # YOUR CODE HERE

        # Then store it into a list
        # YOUR CODE HERE

        # Grab SSN and reformat it
        # YOUR CODE HERE
                
        # Then store it into a list
        # YOUR CODE HERE

        # Grab the states and use the dictionary to find the replacement
        # YOUR CODE HERE

        # Then store the abbreviation into a list
        # YOUR CODE HERE

# Zip all of the new lists together
# YOUR CODE HERE


# Write all of the election data to csv
# YOUR CODE HERE
# Out:
#   File "<ipython-input-10-8df63d2748ea>", line 7
#     for row in reader:
#     ^
# IndentationError: unexpected indent
